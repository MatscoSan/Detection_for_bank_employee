# %% [markdown]
# # Customer class

# %%
class Customer :
    def __init__(self, id, parent = None, role = None):
        self.id = id
        self.parent = parent
        self.role = role
        if (role == 'M') :
            self.role = "Member"
        if (role == 'VP') :
            self.role = "Viewing Party"
        if (role == 'B') :
            self.role = "Business"

# %% [markdown]
# # Create df and imports

# %%
import pandas as pd

df = pd.read_csv('partner_role.csv')
display(df)
# Out:
#                                 partner_id entity_type  \
# 0     06c41ef1-2f8f-4ae5-9203-91d96ea8b97f          BR
# 1     d25181ee-e77a-498e-8e10-69d0e38ef45c          BR
# 2     70e297f9-5729-4d72-b25e-d8e93b50e7d5          BR
# 3     09bbbe2b-bfbc-4573-947a-f3f47814e19f          BR
# 4     d640037a-0eac-4f31-be45-06c67452060f          BR
# ...                                    ...         ...
# 4358  890c6a97-8605-4f1a-8626-b6a8362190a1          BR
# 4359  2469e8af-f398-4186-8551-f30ccba1e3d8          BR
# 4360  8022ba7f-998d-40d3-be23-83d708a6d1f5          BR
# 4361  41f282bc-50a2-44e6-8693-21315e9ecc54          BR
# 4362  ade97d7b-c104-44e4-9adf-e02df028f85f          BR
#
#                                  entity_id relationship_start_date  \
# 0     23cf52a5-631b-4476-8593-46b94f161a6f              2013-04-11
# 1     fd5863b4-fa6b-4b04-a4d8-19bb1fdc98b4              2015-12-10
# 2     fbe6947a-a0ed-4e62-a722-544b447e0530              2019-10-09
# 3     c057d22d-5ef0-4f08-9eba-e202a93c9935              2015-01-18
# 4     fb10b30b-e364-4592-84dd-75fd17a5c3d5              2019-12-31
# ...                                    ...                     ...
# 4358  890c6a97-8605-4f1a-8626-b6a8362190a1                     NaN
# 4359  2469e8af-f398-4186-8551-f30ccba1e3d8                     NaN
# 4360  8022ba7f-998d-40d3-be23-83d708a6d1f5                     NaN
# 4361  41f282bc-50a2-44e6-8693-21315e9ecc54                     NaN
# 4362  ade97d7b-c104-44e4-9adf-e02df028f85f                     NaN
#
#       relationship_end_date br_type_code  \
# 0                       NaN           VP
# 1                       NaN           VP
# 2                       NaN           VP
# 3                       NaN           VP
# 4                       NaN           VP
# ...                     ...          ...
# 4358                    NaN          NaN
# 4359                    NaN          NaN
# 4360                    NaN          NaN
# 4361                    NaN          NaN
# 4362                    NaN          NaN
#
#                      associated_partner_id partner_class_code
# 0                                      NaN                NaN
# 1                                      NaN                NaN
# 2                                      NaN                NaN
# 3                                      NaN                NaN
# 4                                      NaN                NaN
# ...                                    ...                ...
# 4358  670685c9-188e-48b6-9094-af40c0b5e8ff                  B
# 4359  2c3eaacb-644f-4a9a-9a1a-e707993afadc                  B
# 4360  a9029312-93bb-4f8a-b327-ac352da7d9a0                  B
# 4361  164c22d9-1231-4b26-b728-8577dcd168ed                  B
# 4362  9c7e301c-94c1-4014-a745-458c8b732a1f                  B
#
# [4363 rows x 8 columns]

# %% [markdown]
# ## Relations

# %%
df1 = df.drop(columns=["relationship_start_date", "relationship_end_date", "partner_class_code"])
customers_relationship = []

for index, row in df1.iterrows():
    if row['entity_type'] == "BR": 
        customer = Customer(row['partner_id'], row['associated_partner_id'], row['br_type_code'])  
        customers_relationship.append(customer)
# Out:
# [<__main__.Customer object at 0x77af9ab43ef0>, <__main__.Customer object at 0x77af9ab43e90>, <__main__.Customer object at 0x77af9ab43b60>, <__main__.Customer object at 0x77af9ab43b00>, <__main__.Customer object at 0x77af9ab43fe0>, <__main__.Customer object at 0x77af9ab43380>, <__main__.Customer object at 0x77af9ab43d70>, <__main__.Customer object at 0x77af9ab43da0>, <__main__.Customer object at 0x77af9ab43b